# %%
import requests
from PIL import Image

# %%
subscription_key="98c0050da5aa48408a43ff9d91076155"

# %%
assert subscription_key

# %%
face_api_url = 'https://20210503ak-python.cognitiveservices.azure.com/face/v1.0/detect'

# %%
img = Image.open("akkey.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x399 at 0x7FA84558E2B0>

# %%
with open("akkey.jpg","rb")as f:
    binary_img= f.read()

# %%
#binary_img

# %%
headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': subscription_key}

params = {
    'returnFaceId': 'true',
    'returnFaceAttributes':'age,gender,emotion,smile,hair'
}

res = requests.post(face_api_url, params=params,headers=headers, data=binary_img)
res
# Out:
# <Response [200]>

# %%
result= res.json()
result
# Out:
# [{'faceId': 'da19f920-39d0-467b-a150-6b51c2b19fcf',
#   'faceRectangle': {'top': 119, 'left': 140, 'width': 201, 'height': 201},
#   'faceAttributes': {'smile': 0.0,
#    'gender': 'male',
#    'age': 23.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.0,
#     'neutral': 0.997,
#     'sadness': 0.002,
#     'surprise': 0.0},
#    'hair': {'bald': 0.1,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 0.98},
#      {'color': 'other', 'confidence': 0.62},
#      {'color': 'brown', 'confidence': 0.6},
#      {'color': 'gray', 'confidence': 0.38},
#      {'color': 'blond', 'confidence': 0.1},
#      {'color': 'red', 'confidence': 0.1},
#      {'color': 'white', 'confidence': 0.0}]}}}]

# %%
rect=result[0]['faceRectangle']
rect
# Out:
# {'top': 119, 'left': 140, 'width': 201, 'height': 201}

# %%
from PIL import ImageDraw
#image内に図形の書き込み
draw = ImageDraw.Draw(img)

# %%
draw.rectangle(
    [
        rect['left'],rect['top'],
        rect['left']+rect['width'],rect['top']+rect['height'] #rectangleは左上と右下の座標だけでOK
    ],fill=None, outline='red', width=1)

#draw.rectangle([x,y], fill =None, outline='color',width=幅)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x399 at 0x7FA84558E2B0>

# %%
import requests
from PIL import Image
from PIL import ImageDraw
import io

subscription_key="98c0050da5aa48408a43ff9d91076155"
assert subscription_key

face_api_url = 'https://20210503ak-python.cognitiveservices.azure.com/face/v1.0/detect'
img = Image.open("people.jpg")
with io.bytesIO() as output:
    image.save(output, format='jpg')
    binary_img=output.getvalue() #バイナリの取得
    
    
# with open("people.jpg","rb")as f:
#     binary_img= f.read()
    
headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': subscription_key}

params = {
    'returnFaceId': 'true',
    'returnFaceAttributes':'age,gender,emotion,smile,hair'
}

res = requests.post(face_api_url, params=params,headers=headers, data=binary_img)

results= res.json()

for result in results:
    rect=result['faceRectangle']

    draw = ImageDraw.Draw(img)
    draw.rectangle(
        [
            rect['left'],rect['top'],
            rect['left']+rect['width'],rect['top']+rect['height'] #rectangleは左上と右下の座標だけでOK
        ],fill=None, outline='red', width=5)


img
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-2fa49a7f94f5> in <module>
#       9 face_api_url = 'https://20210503ak-python.cognitiveservices.azure.com/face/v1.0/detect'
#      10 img = Image.open("people.jpg")
# ---> 11 with io.bytesIO() as output:
#      12     image.save(output, format='jpg')
#      13     binary_img=output.getvalue() #バイナリの取得
#
# AttributeError: module 'io' has no attribute 'bytesIO'

# %%
result
# Out:
# [{'faceId': 'b498892c-79d9-40c6-ae26-12a6815904c5',
#   'faceRectangle': {'top': 190, 'left': 1412, 'width': 252, 'height': 252},
#   'faceAttributes': {'smile': 1.0,
#    'gender': 'male',
#    'age': 33.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'hair': {'bald': 0.06,
#     'invisible': False,
#     'hairColor': [{'color': 'black', 'confidence': 0.95},
#      {'color': 'brown', 'confidence': 0.83},
#      {'color': 'other', 'confidence': 0.52},
#      {'color': 'gray', 'confidence': 0.28},
#      {'color': 'red', 'confidence': 0.26},
#      {'color': 'blond', 'confidence': 0.07},
#      {'color': 'white', 'confidence': 0.0}]}}},
#  {'faceId': '9b38d12e-fa70-48ff-943b-b8a0ea497fdb',
#   'faceRectangle': {'top': 358, 'left': 1052, 'width': 187, 'height': 187},
#   'faceAttributes': {'smile': 1.0,
#    'gender': 'female',
#    'age': 25.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'hair': {'bald': 0.03,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 0.99},
#      {'color': 'red', 'confidence': 0.94},
#      {'color': 'blond', 'confidence': 0.26},
#      {'color': 'other', 'confidence': 0.21},
#      {'color': 'black', 'confidence': 0.1},
#      {'color': 'gray', 'confidence': 0.04},
#      {'color': 'white', 'confidence': 0.0}]}}},
#  {'faceId': '4d207867-eac2-4127-9c60-c7e346227673',
#   'faceRectangle': {'top': 287, 'left': 490, 'width': 185, 'height': 185},
#   'faceAttributes': {'smile': 1.0,
#    'gender': 'male',
#    'age': 33.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'hair': {'bald': 0.08,
#     'invisible': False,
#     'hairColor': [{'color': 'blond', 'confidence': 1.0},
#      {'color': 'brown', 'confidence': 0.74},
#      {'color': 'gray', 'confidence': 0.44},
#      {'color': 'red', 'confidence': 0.36},
#      {'color': 'other', 'confidence': 0.15},
#      {'color': 'black', 'confidence': 0.02},
#      {'color': 'white', 'confidence': 0.0}]}}},
#  {'faceId': 'dce8a87b-b109-414b-a4d8-842142db0d78',
#   'faceRectangle': {'top': 371, 'left': 724, 'width': 167, 'height': 167},
#   'faceAttributes': {'smile': 1.0,
#    'gender': 'female',
#    'age': 27.0,
#    'emotion': {'anger': 0.0,
#     'contempt': 0.0,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 1.0,
#     'neutral': 0.0,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'hair': {'bald': 0.04,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 0.99},
#      {'color': 'blond', 'confidence': 0.98},
#      {'color': 'red', 'confidence': 0.29},
#      {'color': 'gray', 'confidence': 0.23},
#      {'color': 'black', 'confidence': 0.05},
#      {'color': 'other', 'confidence': 0.04},
#      {'color': 'white', 'confidence': 0.0}]}}}]
